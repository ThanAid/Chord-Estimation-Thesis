# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
def plot_accuracy(epochs: list, t_acc: list, vall_acc: list) -> None:
    """Plots"""
    plt.figure(figsize=(6, 4))
    sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy', marker='o')
    sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy', marker='o')
    plt.title('Accuracy per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.xticks(epochs)
    # plt.yticks([0.42, 0.43, 0.44, 0.45])
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Naive CNN

# %%
# Data
epochs = list(range(1, 11))  # Epoch numbers
train_accuracy = [0.4234, 0.4316, 0.4315, 0.4314, 0.4311, 0.4308, 0.4306, 0.4303, 0.4301, 0.4296]  # Training accuracy
val_accuracy = [0.4305, 0.4305, 0.4310, 0.4304, 0.4309, 0.4300, 0.4285, 0.4302, 0.4274, 0.4279]  # Validation accuracy

# Plot
plot_accuracy(epochs, train_accuracy, val_accuracy)

# %% [markdown]
# # Naive CNN root

# %%
# Accuracy data
epochs = list(range(1, 11))
train_accuracy = [0.5988, 0.6069, 0.6085, 0.6096, 0.6099, 0.6103, 0.6106, 0.6109, 0.6110, 0.6111]
val_accuracy = [0.5817, 0.5852, 0.5854, 0.5849, 0.5844, 0.5853, 0.5859, 0.5851, 0.5857, 0.5854]

# Plot
plot_accuracy(epochs, train_accuracy, val_accuracy)

# %% [markdown]
# # 1D CNN

# %% [markdown]
# ## Root

# %%
# Accuracy and loss data
train_loss = [1.7275, 1.2206, 1.1738, 1.1508, 1.1354, 1.1231, 1.1132, 1.1053, 1.0995, 1.0941,
              1.0902, 1.0864, 1.0832, 1.0807, 1.0769, 1.0736, 1.0709, 1.0690, 1.0668, 1.0654,
              1.0638, 1.0624, 1.0610, 1.0597, 1.0583, 1.0574, 1.0566, 1.0546, 1.0540, 1.0526]
train_accuracy = [0.4501, 0.6403, 0.6542, 0.6605, 0.6649, 0.6681, 0.6710, 0.6733, 0.6750, 0.6763,
                  0.6775, 0.6787, 0.6794, 0.6802, 0.6812, 0.6821, 0.6830, 0.6832, 0.6842, 0.6844,
                  0.6846, 0.6850, 0.6853, 0.6856, 0.6863, 0.6862, 0.6867, 0.6870, 0.6876, 0.6879]
val_loss = [1.2381, 1.1899, 1.1854, 1.1649, 1.1877, 1.1866, 1.1738, 1.1865, 1.2045, 1.1797,
            1.2098, 1.1913, 1.2192, 1.2044, 1.2082, 1.1938, 1.2555, 1.2240, 1.2753, 1.2836,
            1.3118, 1.2630, 1.3497, 1.3414, 1.2996, 1.3740, 1.3070, 1.2665, 1.2848, 1.4103]
val_accuracy = [0.6412, 0.6559, 0.6536, 0.6626, 0.6566, 0.6564, 0.6607, 0.6577, 0.6523, 0.6590,
                0.6491, 0.6552, 0.6500, 0.6534, 0.6513, 0.6550, 0.6372, 0.6457, 0.6318, 0.6272,
                0.6103, 0.6284, 0.5955, 0.5999, 0.6153, 0.5830, 0.6146, 0.6255, 0.6190, 0.5690]

epochs = range(1, len(train_loss) + 1)

# Plot
plt.figure(figsize=(8, 6))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy', marker='o')
plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(epochs)
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs, y=train_loss, label='Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss, label='Validation Loss', marker='o')
plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bass

# %%
# Accuracy and loss data
train_loss = [1.1375, 1.0973, 1.0882, 1.0831, 1.0787, 1.0752, 1.0725, 1.0706, 1.0684, 1.0673]
train_accuracy = [0.6698, 0.6772, 0.6795, 0.6806, 0.6817, 0.6828, 0.6834, 0.6839, 0.6844, 0.6850]
val_loss = [1.1350, 1.1251, 1.1368, 1.1272, 1.1328, 1.1210, 1.1172, 1.1246, 1.1245, 1.1359]
val_accuracy = [0.6722, 0.6743, 0.6717, 0.6733, 0.6725, 0.6757, 0.6754, 0.6746, 0.6739, 0.6711]

epochs = range(1, len(train_loss) + 1)

# Plot
plt.figure(figsize=(8, 6))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(epochs)
plt.yticks([0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs, y=train_loss, label='Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss, label='Validation Loss', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
# plt.yticks([0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Triad

# %%
# Accuracy and loss data
train_loss = [0.6153, 0.5818, 0.5738, 0.5686, 0.5656, 0.5631, 0.5612, 0.5599, 0.5585, 0.5574]
train_accuracy = [0.7855, 0.7957, 0.7981, 0.7993, 0.8002, 0.8007, 0.8013, 0.8016, 0.8021, 0.8020]
val_loss = [0.7077, 0.7019, 0.7078, 0.7151, 0.7093, 0.6699, 0.6997, 0.7014, 0.6749, 0.6917]
val_accuracy = [0.7472, 0.7525, 0.7493, 0.7512, 0.7502, 0.7579, 0.7505, 0.7532, 0.7583, 0.7558]

epochs = range(1, len(train_loss) + 1)

# Plot
plt.figure(figsize=(8, 6))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(epochs)
plt.yticks([0.70, 0.75, 0.80, 0.85])
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs, y=train_loss, label='Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss, label='Validation Loss', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
# plt.yticks([0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ext1

# %%
# Loss and accuracy data
train_loss = [0.4994, 0.4836, 0.4783, 0.4749, 0.4727, 0.4704, 0.4690, 0.4676, 0.4666, 0.4660]
train_accuracy = [0.8574, 0.8576, 0.8577, 0.8578, 0.8580, 0.8581, 0.8582, 0.8584, 0.8585, 0.8585]
val_loss = [0.5413, 0.5232, 0.5238, 0.5237, 0.5278, 0.5259, 0.5188, 0.5263, 0.5311, 0.5271]
val_accuracy = [0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506]
epochs = range(1, len(train_loss) + 1)

# Plot
plt.figure(figsize=(8, 6))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(epochs)
# plt.yticks([0.70, 0.75, 0.80, 0.85])
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs, y=train_loss, label='Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss, label='Validation Loss', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
# plt.yticks([0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ext2

# %%
# Define the epoch numbers
epochs = range(1, 11)

# Define the training and validation accuracies
train_accuracy = [0.9769, 0.9769, 0.9770, 0.9769, 0.9769, 0.9769, 0.9770, 0.9770, 0.9770, 0.9770]
val_accuracy = [0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776]
train_loss = [0.1104, 0.1060, 0.1046, 0.1041, 0.1036, 0.1034, 0.1031, 0.1027, 0.1028, 0.1025]
val_loss = [0.1054, 0.1047, 0.1053, 0.1078, 0.1065, 0.1068, 0.1048, 0.1087, 0.1069, 0.1059]


# Plot
plt.figure(figsize=(8, 6))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(epochs)
# plt.yticks([0.90, 0,925, 0,95, 0,975])
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs, y=train_loss, label='Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss, label='Validation Loss', marker='o')
# plt.axvline(x=10, color='red', linestyle='--', label='Epoch 10')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
# plt.yticks([0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2D vs 1D

# %% [markdown]
# ## Root

# %%
# Model 2 - Root (Existing accuracy and loss data)
train_loss_old = [1.7275, 1.2206, 1.1738, 1.1508, 1.1354, 1.1231, 1.1132, 1.1053, 1.0995, 1.0941,
                  1.0902, 1.0864, 1.0832, 1.0807, 1.0769, 1.0736, 1.0709, 1.0690, 1.0668, 1.0654,
                  1.0638, 1.0624, 1.0610, 1.0597, 1.0583, 1.0574, 1.0566, 1.0546, 1.0540, 1.0526]
train_accuracy_old = [0.4501, 0.6403, 0.6542, 0.6605, 0.6649, 0.6681, 0.6710, 0.6733, 0.6750, 0.6763,
                      0.6775, 0.6787, 0.6794, 0.6802, 0.6812, 0.6821, 0.6830, 0.6832, 0.6842, 0.6844,
                      0.6846, 0.6850, 0.6853, 0.6856, 0.6863, 0.6862, 0.6867, 0.6870, 0.6876, 0.6879]
val_loss_old = [1.2381, 1.1899, 1.1854, 1.1649, 1.1877, 1.1866, 1.1738, 1.1865, 1.2045, 1.1797,
                1.2098, 1.1913, 1.2192, 1.2044, 1.2082, 1.1938, 1.2555, 1.2240, 1.2753, 1.2836,
                1.3118, 1.2630, 1.3497, 1.3414, 1.2996, 1.3740, 1.3070, 1.2665, 1.2848, 1.4103]
val_accuracy_old = [0.6412, 0.6559, 0.6536, 0.6626, 0.6566, 0.6564, 0.6607, 0.6577, 0.6523, 0.6590,
                    0.6491, 0.6552, 0.6500, 0.6534, 0.6513, 0.6550, 0.6372, 0.6457, 0.6318, 0.6272,
                    0.6103, 0.6284, 0.5955, 0.5999, 0.6153, 0.5830, 0.6146, 0.6255, 0.6190, 0.5690]

# Model 3 - Root (New accuracy and loss data)
train_loss_new = [1.4262, 0.7221, 0.6504, 0.6063, 0.5723, 0.5456, 0.5259, 0.5012, 0.4822, 0.4680,
                  0.4526, 0.4386, 0.4244, 0.4119, 0.3984, 0.3895, 0.3772, 0.3668, 0.3554, 0.3464,
                  0.3367, 0.3268, 0.3187, 0.3087, 0.3012, 0.2925, 0.2862, 0.2782, 0.2714, 0.2654,
                  0.2579, 0.2511, 0.2463, 0.2387, 0.2345, 0.2286, 0.2226, 0.2184, 0.2129, 0.2084]
train_accuracy_new = [0.5554, 0.7977, 0.8165, 0.8280, 0.8364, 0.8448, 0.8496, 0.8563, 0.8613, 0.8648,
                      0.8687, 0.8728, 0.8757, 0.8788, 0.8825, 0.8841, 0.8877, 0.8900, 0.8930, 0.8950,
                      0.8974, 0.9001, 0.9024, 0.9043, 0.9063, 0.9085, 0.9102, 0.9127, 0.9143, 0.9157,
                      0.9179, 0.9196, 0.9210, 0.9231, 0.9243, 0.9259, 0.9272, 0.9287, 0.9300, 0.9313]
val_loss_new = [0.7823, 0.7041, 0.6629, 0.6475, 0.6200, 0.6060, 0.5929, 0.5729, 0.5745, 0.5767,
                0.5889, 0.5680, 0.5838, 0.5706, 0.5723, 0.5753, 0.5868, 0.5613, 0.5704, 0.5672,
                0.5689, 0.5703, 0.5876, 0.5862, 0.5827, 0.5694, 0.5636, 0.6014, 0.5973, 0.6146,
                0.6005, 0.6049, 0.6076, 0.6103, 0.6154, 0.6245, 0.6290, 0.6509, 0.6519, 0.6562]
val_accuracy_new = [0.7892, 0.8089, 0.8204, 0.8245, 0.8321, 0.8338, 0.8426, 0.8455, 0.8436, 0.8478,
                    0.8493, 0.8491, 0.8502, 0.8483, 0.8533, 0.8534, 0.8566, 0.8539, 0.8563, 0.8557,
                    0.8565, 0.8586, 0.8492, 0.8569, 0.8559, 0.8529, 0.8561, 0.8540, 0.8550, 0.8552,
                    0.8541, 0.8521, 0.8538, 0.8526, 0.8549, 0.8547, 0.8528, 0.8555, 0.8564, 0.8566]

epochs_old = range(1, len(train_loss_old) + 1)
epochs_new = range(1, len(train_loss_new) + 1)

# Plot
fig, axes = plt.subplots(2, 1, figsize=(10, 8))

# Accuracy plot
sns.lineplot(x=epochs_old, y=train_accuracy_old, label='Model 2 - Root - Training Accuracy', marker='o', color='blue', ax=axes[0])
sns.lineplot(x=epochs_old, y=val_accuracy_old, label='Model 2 - Root - Validation Accuracy', marker='o', color='orange', ax=axes[0])
sns.lineplot(x=epochs_new, y=train_accuracy_new, label='Model 3 - Root - Training Accuracy', marker='o', color='green', ax=axes[0])
sns.lineplot(x=epochs_new, y=val_accuracy_new, label='Model 3 - Root - Validation Accuracy', marker='o', color='red', ax=axes[0])

axes[0].axvline(x=10, color='gray', linestyle='--', label='Epoch 10')
axes[0].set_title('Accuracy per Epoch')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True)

# Loss plot
sns.lineplot(x=epochs_old, y=train_loss_old, label='Model 2 - Root - Training Loss', marker='o', color='blue', ax=axes[1])
sns.lineplot(x=epochs_old, y=val_loss_old, label='Model 2 - Root - Validation Loss', marker='o', color='orange', ax=axes[1])
sns.lineplot(x=epochs_new, y=train_loss_new, label='Model 3 - Root - Training Loss', marker='o', color='green', ax=axes[1])
sns.lineplot(x=epochs_new, y=val_loss_new, label='Model 3 - Root - Validation Loss', marker='o', color='red', ax=axes[1])

axes[1].axvline(x=10, color='gray', linestyle='--', label='Epoch 10')
axes[1].set_title('Loss per Epoch')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## comparison with weitghts

# %%
# Model 3 - Root (New accuracy and loss data)
train_loss_model3 = [1.4262, 0.7221, 0.6504, 0.6063, 0.5723, 0.5456, 0.5259, 0.5012, 0.4822, 0.4680,
                  0.4526, 0.4386, 0.4244, 0.4119, 0.3984, 0.3895, 0.3772, 0.3668, 0.3554, 0.3464,
                  0.3367, 0.3268, 0.3187, 0.3087, 0.3012, 0.2925, 0.2862, 0.2782, 0.2714, 0.2654,
                  0.2579, 0.2511, 0.2463, 0.2387, 0.2345, 0.2286, 0.2226, 0.2184, 0.2129, 0.2084]
train_accuracy_model3 = [0.5554, 0.7977, 0.8165, 0.8280, 0.8364, 0.8448, 0.8496, 0.8563, 0.8613, 0.8648,
                      0.8687, 0.8728, 0.8757, 0.8788, 0.8825, 0.8841, 0.8877, 0.8900, 0.8930, 0.8950,
                      0.8974, 0.9001, 0.9024, 0.9043, 0.9063, 0.9085, 0.9102, 0.9127, 0.9143, 0.9157,
                      0.9179, 0.9196, 0.9210, 0.9231, 0.9243, 0.9259, 0.9272, 0.9287, 0.9300, 0.9313]
val_loss_model3 = [0.7823, 0.7041, 0.6629, 0.6475, 0.6200, 0.6060, 0.5929, 0.5729, 0.5745, 0.5767,
                0.5889, 0.5680, 0.5838, 0.5706, 0.5723, 0.5753, 0.5868, 0.5613, 0.5704, 0.5672,
                0.5689, 0.5703, 0.5876, 0.5862, 0.5827, 0.5694, 0.5636, 0.6014, 0.5973, 0.6146,
                0.6005, 0.6049, 0.6076, 0.6103, 0.6154, 0.6245, 0.6290, 0.6509, 0.6519, 0.6562]
val_accuracy_model3 = [0.7892, 0.8089, 0.8204, 0.8245, 0.8321, 0.8338, 0.8426, 0.8455, 0.8436, 0.8478,
                    0.8493, 0.8491, 0.8502, 0.8483, 0.8533, 0.8534, 0.8566, 0.8539, 0.8563, 0.8557,
                    0.8565, 0.8586, 0.8492, 0.8569, 0.8559, 0.8529, 0.8561, 0.8540, 0.8550, 0.8552,
                    0.8541, 0.8521, 0.8538, 0.8526, 0.8549, 0.8547, 0.8528, 0.8555, 0.8564, 0.8566]


# Data for Model 3 with weights
train_loss_model2 = [2.2651, 1.2793, 0.8645, 0.7642, 0.7052, 0.6700, 0.6393, 0.6145, 0.5972, 0.5800,
                     0.5649, 0.5494, 0.5355, 0.5268, 0.5142, 0.5028, 0.4928, 0.4837, 0.4719, 0.4649,
                     0.4556, 0.4486, 0.4395, 0.4329, 0.4246, 0.4196, 0.4108, 0.4052, 0.3997, 0.3901,
                     0.3878, 0.3778, 0.3723, 0.3672, 0.3613, 0.3560, 0.3512, 0.3440, 0.3412, 0.3357]
train_accuracy_model2 = [0.1764, 0.5942, 0.7410, 0.7755, 0.7943, 0.8038, 0.8120, 0.8184, 0.8227, 0.8273,
                         0.8317, 0.8353, 0.8393, 0.8419, 0.8453, 0.8477, 0.8515, 0.8530, 0.8569, 0.8588,
                         0.8616, 0.8624, 0.8653, 0.8674, 0.8694, 0.8702, 0.8728, 0.8743, 0.8757, 0.8780,
                         0.8787, 0.8811, 0.8827, 0.8840, 0.8855, 0.8865, 0.8883, 0.8898, 0.8905, 0.8921]
val_loss_model2 = [2.0211, 0.9807, 0.8263, 0.7647, 0.7447, 0.7321, 0.7155, 0.6975, 0.6780, 0.6727,
                   0.6712, 0.6738, 0.6565, 0.6593, 0.6406, 0.6562, 0.6449, 0.6436, 0.6438, 0.6658,
                   0.6478, 0.6545, 0.6599, 0.6425, 0.6489, 0.6473, 0.6344, 0.6535, 0.6597, 0.6505,
                   0.6495, 0.6846, 0.6574, 0.6509, 0.6739, 0.6750, 0.6628, 0.6700, 0.6622, 0.6762]
val_accuracy_model2 = [0.3098, 0.7158, 0.7696, 0.7895, 0.7946, 0.7986, 0.8000, 0.8080, 0.8117, 0.8142,
                       0.8151, 0.8152, 0.8198, 0.8208, 0.8239, 0.8198, 0.8252, 0.8250, 0.8280, 0.8227,
                       0.8262, 0.8238, 0.8273, 0.8316, 0.8299, 0.8283, 0.8333, 0.8280, 0.8306, 0.8327,
                       0.8287, 0.8284, 0.8291, 0.8319, 0.8301, 0.8333, 0.8322, 0.8279, 0.8297, 0.8275]

epochs = range(1, len(train_loss_model2) + 1)


# Plot
plt.figure(figsize=(10, 8))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs, y=train_accuracy_model2, label='Model 3 - Weights Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy_model2, label='Model 3 - Weights Validation Accuracy', marker='o')
sns.lineplot(x=epochs, y=train_accuracy_model3, label='Model 3 Training Accuracy', marker='o')
sns.lineplot(x=epochs, y=val_accuracy_model3, label='Model 3 Validation Accuracy', marker='o')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(epochs)
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs, y=train_loss_model2, label='Model 3 - Weights Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss_model2, label='Model 3 - Weights Validation Loss', marker='o')
sns.lineplot(x=epochs, y=train_loss_model3, label='Model 3 Training Loss', marker='o')
sns.lineplot(x=epochs, y=val_loss_model3, label='Model 3 Validation Loss', marker='o')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bass

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Model 3 data
model3_train_loss = [0.7486, 0.5419, 0.4869, 0.4460, 0.4144, 0.3824, 0.3559, 0.3319, 0.3078, 0.2877, 0.2680, 0.2508, 0.2342, 0.2196, 0.2049, 0.1927, 0.1810, 0.1703, 0.1604, 0.1518, 0.1441, 0.1368, 0.1300, 0.1239, 0.1190, 0.1141, 0.1094, 0.1048, 0.1014, 0.0984]
model3_train_accuracy = [0.7897, 0.8490, 0.8627, 0.8726, 0.8795, 0.8871, 0.8936, 0.8994, 0.9056, 0.9108, 0.9160, 0.9208, 0.9256, 0.9294, 0.9337, 0.9374, 0.9407, 0.9440, 0.9470, 0.9496, 0.9521, 0.9543, 0.9564, 0.9583, 0.9599, 0.9614, 0.9629, 0.9643, 0.9654, 0.9662]
model3_val_loss = [0.6122, 0.5552, 0.5431, 0.5296, 0.5344, 0.5331, 0.5399, 0.5307, 0.5304, 0.5342, 0.5437, 0.5451, 0.5619, 0.5531, 0.5656, 0.5920, 0.5755, 0.6214, 0.6036, 0.6136, 0.6429, 0.6606, 0.6601, 0.6574, 0.6879, 0.6749, 0.7045, 0.7031, 0.7093, 0.7286]
model3_val_accuracy = [0.8388, 0.8529, 0.8562, 0.8568, 0.8563, 0.8623, 0.8556, 0.8595, 0.8601, 0.8584, 0.8605, 0.8588, 0.8536, 0.8605, 0.8567, 0.8576, 0.8537, 0.8567, 0.8587, 0.8524, 0.8542, 0.8539, 0.8575, 0.8545, 0.8562, 0.8565, 0.8555, 0.8559, 0.8535, 0.8555]

# Model 2 data
model2_train_loss = [1.1375, 1.0973, 1.0882, 1.0831, 1.0787, 1.0752, 1.0725, 1.0706, 1.0684, 1.0673]
model2_train_accuracy = [0.6698, 0.6772, 0.6795, 0.6806, 0.6817, 0.6828, 0.6834, 0.6839, 0.6844, 0.6850]
model2_val_loss = [1.1350, 1.1251, 1.1368, 1.1272, 1.1328, 1.1210, 1.1172, 1.1246, 1.1245, 1.1359]
model2_val_accuracy = [0.6722, 0.6743, 0.6717, 0.6733, 0.6725, 0.6757, 0.6754, 0.6746, 0.6739, 0.6711]

epochs_model2 = range(1, len(model2_train_loss) + 1)
epochs_model3 = range(1, len(model3_train_loss) + 1)

# Plot
plt.figure(figsize=(10, 8))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs_model2, y=model2_train_accuracy, label='Model 2 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_accuracy, label='Model 2 Validation Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_accuracy, label='Model 3 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_accuracy, label='Model 3 Validation Accuracy', marker='o')
plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs_model2, y=model2_train_loss, label='Model 2 Training Loss', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_loss, label='Model 2 Validation Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_loss, label='Model 3 Training Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_loss, label='Model 3 Validation Loss', marker='o')
plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Triad

# %%
model3_train_loss = [0.4715, 0.3215, 0.2573, 0.2100, 0.1727, 0.1443, 0.1221, 0.1055, 0.0914, 0.0805, 0.0713, 0.0649, 0.0583, 0.0530, 0.0491, 0.0469, 0.0431, 0.0393, 0.0370, 0.0357, 0.0346, 0.0316, 0.0305, 0.0284, 0.0271, 0.0268, 0.0253, 0.0252, 0.0239, 0.0226]
model3_val_loss = [0.4002, 0.3431, 0.3278, 0.2571, 0.2301, 0.2286, 0.2114, 0.1950, 0.2034, 0.1851, 0.1729, 0.1704, 0.1680, 0.1799, 0.1706, 0.1677, 0.1536, 0.1627, 0.1777, 0.1578, 0.1549, 0.1542, 0.1484, 0.1499, 0.1627, 0.1454, 0.1499, 0.1470, 0.1635, 0.1626]
model3_train_accuracy = [0.8340, 0.8855, 0.9071, 0.9239, 0.9376, 0.9478, 0.9557, 0.9616, 0.9666, 0.9706, 0.9739, 0.9760, 0.9785, 0.9805, 0.9819, 0.9827, 0.9841, 0.9855, 0.9863, 0.9867, 0.9871, 0.9883, 0.9886, 0.9895, 0.9898, 0.9899, 0.9905, 0.9906, 0.9910, 0.9915]
model3_val_accuracy = [0.8616, 0.8810, 0.8806, 0.9080, 0.9166, 0.9201, 0.9266, 0.9314, 0.9294, 0.9374, 0.9384, 0.9414, 0.9448, 0.9425, 0.9451, 0.9466, 0.9488, 0.9489, 0.9469, 0.9513, 0.9530, 0.9526, 0.9549, 0.9544, 0.9525, 0.9559, 0.9549, 0.9564, 0.9539, 0.9553]

# old model
# Accuracy and loss data
model2_train_loss = [0.6153, 0.5818, 0.5738, 0.5686, 0.5656, 0.5631, 0.5612, 0.5599, 0.5585, 0.5574]
model2_train_accuracy = [0.7855, 0.7957, 0.7981, 0.7993, 0.8002, 0.8007, 0.8013, 0.8016, 0.8021, 0.8020]
model2_val_loss = [0.7077, 0.7019, 0.7078, 0.7151, 0.7093, 0.6699, 0.6997, 0.7014, 0.6749, 0.6917]
model2_val_accuracy = [0.7472, 0.7525, 0.7493, 0.7512, 0.7502, 0.7579, 0.7505, 0.7532, 0.7583, 0.7558]

epochs_model2 = range(1, len(model2_train_loss) + 1)
epochs_model3 = range(1, len(model3_train_loss) + 1)

# Plot
plt.figure(figsize=(10, 8))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs_model2, y=model2_train_accuracy, label='Model 2 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_accuracy, label='Model 2 Validation Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_accuracy, label='Model 3 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_accuracy, label='Model 3 Validation Accuracy', marker='o')
# plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs_model2, y=model2_train_loss, label='Model 2 Training Loss', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_loss, label='Model 2 Validation Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_loss, label='Model 3 Training Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_loss, label='Model 3 Validation Loss', marker='o')
# plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ext1

# %%
# Model 2
model2_train_loss = [0.4994, 0.4836, 0.4783, 0.4749, 0.4727, 0.4704, 0.4690, 0.4676, 0.4666, 0.4660]
model2_train_accuracy = [0.8574, 0.8576, 0.8577, 0.8578, 0.8580, 0.8581, 0.8582, 0.8584, 0.8585, 0.8585]
model2_val_loss = [0.5413, 0.5232, 0.5238, 0.5237, 0.5278, 0.5259, 0.5188, 0.5263, 0.5311, 0.5271]
model2_val_accuracy = [0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506, 0.8506]

# Model 3
model3_train_loss = [0.4680, 0.3754, 0.2990, 0.2407, 0.1896, 0.1550, 0.1271, 0.1052, 0.0893, 0.0776, 0.0658, 0.0587, 0.0519, 0.0472, 0.0443, 0.0391, 0.0364, 0.0330, 0.0307, 0.0283, 0.0256, 0.0247, 0.0239, 0.0230, 0.0212, 0.0206, 0.0189, 0.0196, 0.0168, 0.0170]
model3_val_loss = [0.4410, 0.3633, 0.3328, 0.2974, 0.2829, 0.2437, 0.2562, 0.2188, 0.1913, 0.1895, 0.1839, 0.2101, 0.1921, 0.1889, 0.1768, 0.1647, 0.1565, 0.1757, 0.1699, 0.1546, 0.1476, 0.2140, 0.1875, 0.1903, 0.1736, 0.1818, 0.1791, 0.1496, 0.1734, 0.1623]
model3_train_accuracy = [0.8602, 0.8723, 0.8953, 0.9142, 0.9323, 0.9439, 0.9541, 0.9619, 0.9675, 0.9718, 0.9760, 0.9785, 0.9812, 0.9829, 0.9840, 0.9858, 0.9868, 0.9880, 0.9889, 0.9898, 0.9907, 0.9910, 0.9913, 0.9917, 0.9922, 0.9925, 0.9932, 0.9929, 0.9938, 0.9938]
model3_val_accuracy = [0.8472, 0.8679, 0.8823, 0.8869, 0.9008, 0.9102, 0.9028, 0.9226, 0.9312, 0.9318, 0.9359, 0.9267, 0.9377, 0.9389, 0.9431, 0.9470, 0.9499, 0.9463, 0.9483, 0.9517, 0.9529, 0.9444, 0.9485, 0.9487, 0.9526, 0.9506, 0.9521, 0.9565, 0.9544, 0.9558]

epochs_model2 = range(1, len(model2_train_loss) + 1)
epochs_model3 = range(1, len(model3_train_loss) + 1)

# Plot
plt.figure(figsize=(10, 8))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs_model2, y=model2_train_accuracy, label='Model 2 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_accuracy, label='Model 2 Validation Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_accuracy, label='Model 3 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_accuracy, label='Model 3 Validation Accuracy', marker='o')
# plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs_model2, y=model2_train_loss, label='Model 2 Training Loss', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_loss, label='Model 2 Validation Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_loss, label='Model 3 Training Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_loss, label='Model 3 Validation Loss', marker='o')
# plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ext2

# %%
# Model 3
model3_train_loss = [0.1007, 0.0725, 0.0483, 0.0329, 0.0222, 0.0157, 0.0122, 0.0096, 0.0083, 0.0065, 0.0056, 0.0046, 0.0037, 0.0045, 0.0028, 0.0037, 0.0028, 0.0021, 0.0025, 0.0023, 0.0019, 0.0021, 0.0016, 0.0018, 0.0018, 0.0015, 0.0012, 0.0013, 0.0012, 0.0012]
model3_val_loss = [0.1167, 0.0700, 0.0593, 0.0413, 0.0385, 0.0348, 0.0308, 0.0379, 0.0264, 0.0377, 0.0346, 0.0303, 0.0219, 0.0275, 0.0214, 0.0481, 0.0298, 0.0399, 0.0241, 0.0325, 0.0205, 0.0319, 0.0302, 0.0373, 0.0266, 0.0340, 0.0264, 0.0463, 0.0218, 0.0253]
model3_train_accuracy = [0.9777, 0.9803, 0.9856, 0.9894, 0.9924, 0.9945, 0.9956, 0.9965, 0.9970, 0.9976, 0.9981, 0.9983, 0.9987, 0.9983, 0.9990, 0.9986, 0.9990, 0.9992, 0.9991, 0.9991, 0.9993, 0.9992, 0.9994, 0.9993, 0.9993, 0.9995, 0.9996, 0.9995, 0.9996, 0.9996]
model3_val_accuracy = [0.9741, 0.9790, 0.9806, 0.9860, 0.9866, 0.9886, 0.9897, 0.9890, 0.9918, 0.9900, 0.9896, 0.9914, 0.9935, 0.9918, 0.9936, 0.9896, 0.9925, 0.9906, 0.9931, 0.9926, 0.9945, 0.9922, 0.9932, 0.9918, 0.9936, 0.9926, 0.9940, 0.9908, 0.9945, 0.9943]

# Model 2
model2_train_accuracy = [0.9769, 0.9769, 0.9770, 0.9769, 0.9769, 0.9769, 0.9770, 0.9770, 0.9770, 0.9770]
model2_val_accuracy = [0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776, 0.9776]
model2_train_loss = [0.1104, 0.1060, 0.1046, 0.1041, 0.1036, 0.1034, 0.1031, 0.1027, 0.1028, 0.1025]
model2_val_loss = [0.1054, 0.1047, 0.1053, 0.1078, 0.1065, 0.1068, 0.1048, 0.1087, 0.1069, 0.1059]

epochs_model2 = range(1, len(model2_train_loss) + 1)
epochs_model3 = range(1, len(model3_train_loss) + 1)

# Plot
plt.figure(figsize=(10, 8))

# Accuracy plot
plt.subplot(2, 1, 1)
sns.lineplot(x=epochs_model2, y=model2_train_accuracy, label='Model 2 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_accuracy, label='Model 2 Validation Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_accuracy, label='Model 3 Training Accuracy', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_accuracy, label='Model 3 Validation Accuracy', marker='o')
# plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(2, 1, 2)
sns.lineplot(x=epochs_model2, y=model2_train_loss, label='Model 2 Training Loss', marker='o')
sns.lineplot(x=epochs_model2, y=model2_val_loss, label='Model 2 Validation Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_train_loss, label='Model 3 Training Loss', marker='o')
sns.lineplot(x=epochs_model3, y=model3_val_loss, label='Model 3 Validation Loss', marker='o')
# plt.axvline(x=20, color='red', linestyle='--', label='Epoch 20')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(range(1, max(len(epochs_model2), len(epochs_model3)) + 1))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Times

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for training times
data = {
    'Model': ['Model 3'] * 5 + ['Model 2'] * 5 + ['Model 1'],
    'Task': ['root', 'bass', 'triad', 'ext1', 'ext2'] * 2 + ['Naive CNN'],
    'Time (seconds)': [10080.59, 10879.30, 3817.72, 6079.57, 5461.44,
                       10866.14, 9400.42, 2092.86, 2161.84, 1732.12,
                       6447.56]
}

# Create DataFrame
df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Task', y='Time (seconds)', hue='Model', data=df)
plt.title('Training Time in Seconds for Each Model and Task')
plt.show()

# %% [markdown]
# # Accuracies

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for accuracies
data_accuracy = {
    'Model': ['Model 1'] * 2 + ['Model 2'] * 10 + ['Model 3'] * 10,
    'Task': ['Train'] * 1 + ['Validation'] * 1 + 
            ['Train Root', 'Train Bass', 'Train Triad', 'Train Ext1', 'Train Ext2', 
             'Validation Root', 'Validation Bass', 'Validation Triad', 'Validation Ext1', 'Validation Ext2'] + 
            ['Train Root', 'Train Bass', 'Train Triad', 'Train Ext1', 'Train Ext2', 
             'Validation Root', 'Validation Bass', 'Validation Triad', 'Validation Ext1', 'Validation Ext2'],
    'Accuracy': [0.4296, 0.4279, 
                 0.6763, 0.6850, 0.8020, 0.8585, 0.9770, 0.6590, 0.6711, 0.7558, 0.8506, 0.9776,
                 0.9313, 0.9662, 0.9915, 0.9938, 0.9996, 0.8566, 0.8555, 0.9553, 0.9558, 0.9943]
}

# Create DataFrame
df_accuracy = pd.DataFrame(data_accuracy)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Task', y='Accuracy', hue='Model', data=df_accuracy)
plt.xticks(rotation=45, ha='right')
plt.title('Accuracy for Each Model and Task')
plt.show()

# %% [markdown]
# # F1 and ACC

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for evaluation and test scores
evaluation_scores = {
    'Task': ['Root', 'Bass', 'Triad', 'Ext1', 'Ext2'],
    'Accuracy': [86, 86, 96, 96, 99],
    'F1 Macro': [86, 86, 84, 80, 94]
}

test_scores = {
    'Task': ['Root', 'Bass', 'Triad', 'Ext1', 'Ext2'],
    'Accuracy': [83, 81, 96, 98, 99],
    'F1 Macro': [82, 80, 84, 90, 94]
}

# Create DataFrames
df_evaluation = pd.DataFrame(evaluation_scores)
df_test = pd.DataFrame(test_scores)

# Melt the DataFrames to long format for plotting
df_evaluation_melted = pd.melt(df_evaluation, id_vars='Task', var_name='Metric', value_name='Score')
df_test_melted = pd.melt(df_test, id_vars='Task', var_name='Metric', value_name='Score')

# Plotting
fig, axes = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Evaluation Set subplot
sns.barplot(ax=axes[0], data=df_evaluation_melted, y='Task', x='Score', hue='Metric', orient='h')
axes[0].set_title('Scores for Each Task on the Evaluation set')
axes[0].set_xlabel('Score')
axes[0].legend(title='Metric')

# Add numbers on right of the bars in the evaluation set subplot
for p in axes[0].patches:
    axes[0].annotate(format(p.get_width(), '.0f'),
                     (p.get_width(), p.get_y() + p.get_height() / 2.),
                     ha='center', va='center',
                     xytext=(12, 0),  # 12 points horizontal offset
                     textcoords='offset points')

# Test Set subplot
sns.barplot(ax=axes[1], data=df_test_melted, y='Task', x='Score', hue='Metric', orient='h')
axes[1].set_title('Scores for Each Task on the Test set')
axes[1].set_xlabel('Score')
axes[1].set_ylabel('Task')
axes[1].legend(title='Metric')

# Add numbers on right of the bars in the test set subplot
for p in axes[1].patches:
    axes[1].annotate(format(p.get_width(), '.0f'),
                     (p.get_width(), p.get_y() + p.get_height() / 2.),
                     ha='center', va='center',
                     xytext=(12, 0),  # 12 points horizontal offset
                     textcoords='offset points')

plt.tight_layout()
plt.show()
